# %% [markdown]
# <a href="https://colab.research.google.com/github/bikash-bhoi/EIP4/blob/master/Session4%20Assignment/Assignment%204B/Resnet18_cifar10_16ch_cutout_gradcam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):

  """
  p : the probability that random erasing is performed
  s_l, s_h : minimum / maximum proportion of erased area against input image
  r_1, r_2 : minimum / maximum aspect ratio of erased area
  v_l, v_h : minimum / maximum value for erased area
  pixel_level : pixel-level randomization for erased area
  """

  def eraser(input_img):
    img_h, img_w, img_c = input_img.shape
    p_1 = np.random.rand()

    if p_1 > p:
        return input_img

    while True:
        s = np.random.uniform(s_l, s_h) * img_h * img_w
        r = np.random.uniform(r_1, r_2)
        w = int(np.sqrt(s / r))
        h = int(np.sqrt(s * r))
        left = np.random.randint(0, img_w)
        top = np.random.randint(0, img_h)

        if left + w <= img_w and top + h <= img_h:
            break

    if pixel_level:
        c = np.random.uniform(v_l, v_h, (h, w, img_c))
    else:
        c = np.random.uniform(v_l, v_h)

    input_img[top:top + h, left:left + w, :] = c

    return input_img

  return eraser

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = GlobalAveragePooling2D()(x)
    #y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    #y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0017),
              metrics=['accuracy'])
model.summary()
print(model_type)
print(depth)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   272         activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   2320        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 16)   64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 16)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 64)   1088        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 64)   1088        activation_22[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 64)   0           conv2d_27[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 64)   256         add_7[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 16)   1040        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 16)   64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 16)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 16)   2320        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 16)   64          conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 16)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 64)   1088        activation_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 64)   0           add_7[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   4160        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 64)   36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 128)  8320        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  8320        activation_28[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 128)  0           conv2d_34[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         add_9[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 64)   8256        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 128)  8320        activation_31[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           add_9[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 128)    16512       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 128)    512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 128)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    147584      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 128)    512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 128)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 256)    33024       add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 256)    33024       activation_34[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 256)    0           conv2d_41[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 256)    1024        add_11[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 256)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 128)    32896       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 128)    512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    147584      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 128)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 256)    33024       activation_37[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 256)    0           add_11[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 256)    1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 256)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           activation_38[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           2570        global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2
# 20

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}_Ch16.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)
# Out:
# /content/saved_models/cifar10_ResNet20v2_model.{epoch:03d}_Ch16.h5

# %%
#Define LR Scheduler
def lr_schedule(epoch,lr):
    return round(lr * 1/(1 + 0.0019 * epoch), 10)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule,verbose=1)

lr_reducer = ReduceLROnPlateau(factor=0.8,
                               cooldown=0,
                               patience=3,
                               monitor='val_loss',
                               min_lr=0.3e-5)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=15,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.1,
        # set range for random zoom
        zoom_range=0.1,
        # set range for random channel shifts
        channel_shift_range=0.1,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        #Cutout Implementation
        preprocessing_function=get_random_eraser(p=0.2,v_l=0, v_h=1, s_l=0.008, s_h=0.1, pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0017.
# 782/782 [==============================] - 69s 88ms/step - loss: 1.7939 - acc: 0.4649 - val_loss: 1.6806 - val_acc: 0.5039
#
# Epoch 00001: val_acc improved from -inf to 0.50390, saving model to /content/saved_models/cifar10_ResNet20v2_model.001_Ch16.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0016967761.
# 782/782 [==============================] - 53s 68ms/step - loss: 1.3878 - acc: 0.5927 - val_loss: 1.5047 - val_acc: 0.5560
#
# Epoch 00002: val_acc improved from 0.50390 to 0.55600, saving model to /content/saved_models/cifar10_ResNet20v2_model.002_Ch16.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0016903528.
# 782/782 [==============================] - 54s 68ms/step - loss: 1.2339 - acc: 0.6412 - val_loss: 1.2890 - val_acc: 0.6178
#
# Epoch 00003: val_acc improved from 0.55600 to 0.61780, saving model to /content/saved_models/cifar10_ResNet20v2_model.003_Ch16.h5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0016807724.
# 782/782 [==============================] - 53s 67ms/step - loss: 1.1294 - acc: 0.6814 - val_loss: 1.4714 - val_acc: 0.6039
#
# Epoch 00004: val_acc did not improve from 0.61780
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0016680949.
# 782/782 [==============================] - 53s 68ms/step - loss: 1.0533 - acc: 0.7100 - val_loss: 1.4031 - val_acc: 0.6297
#
# Epoch 00005: val_acc improved from 0.61780 to 0.62970, saving model to /content/saved_models/cifar10_ResNet20v2_model.005_Ch16.h5
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0016523971.
# 782/782 [==============================] - 53s 68ms/step - loss: 1.0133 - acc: 0.7235 - val_loss: 1.3005 - val_acc: 0.6634
#
# Epoch 00006: val_acc improved from 0.62970 to 0.66340, saving model to /content/saved_models/cifar10_ResNet20v2_model.006_Ch16.h5
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0013070176.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.9291 - acc: 0.7486 - val_loss: 1.1637 - val_acc: 0.6947
#
# Epoch 00007: val_acc improved from 0.66340 to 0.69470, saving model to /content/saved_models/cifar10_ResNet20v2_model.007_Ch16.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0012898625.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.8971 - acc: 0.7613 - val_loss: 1.2967 - val_acc: 0.6817
#
# Epoch 00008: val_acc did not improve from 0.69470
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0012705502.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.8598 - acc: 0.7722 - val_loss: 1.1410 - val_acc: 0.7011
#
# Epoch 00009: val_acc improved from 0.69470 to 0.70110, saving model to /content/saved_models/cifar10_ResNet20v2_model.009_Ch16.h5
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0012491891.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.8375 - acc: 0.7794 - val_loss: 1.1957 - val_acc: 0.7018
#
# Epoch 00010: val_acc improved from 0.70110 to 0.70180, saving model to /content/saved_models/cifar10_ResNet20v2_model.010_Ch16.h5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0012258971.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.8131 - acc: 0.7869 - val_loss: 0.8871 - val_acc: 0.7679
#
# Epoch 00011: val_acc improved from 0.70180 to 0.76790, saving model to /content/saved_models/cifar10_ResNet20v2_model.011_Ch16.h5
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0012008004.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.7959 - acc: 0.7947 - val_loss: 0.9213 - val_acc: 0.7592
#
# Epoch 00012: val_acc did not improve from 0.76790
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0011740325.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.7835 - acc: 0.7948 - val_loss: 0.9472 - val_acc: 0.7560
#
# Epoch 00013: val_acc did not improve from 0.76790
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0011457329.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.7576 - acc: 0.8054 - val_loss: 0.9302 - val_acc: 0.7712
#
# Epoch 00014: val_acc improved from 0.76790 to 0.77120, saving model to /content/saved_models/cifar10_ResNet20v2_model.014_Ch16.h5
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0008928369.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.7110 - acc: 0.8198 - val_loss: 1.0188 - val_acc: 0.7414
#
# Epoch 00015: val_acc did not improve from 0.77120
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0008680962.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.7006 - acc: 0.8230 - val_loss: 0.9248 - val_acc: 0.7568
#
# Epoch 00016: val_acc did not improve from 0.77120
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0008424847.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.6728 - acc: 0.8301 - val_loss: 1.4341 - val_acc: 0.6621
#
# Epoch 00017: val_acc did not improve from 0.77120
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0006528991.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.6403 - acc: 0.8411 - val_loss: 0.6819 - val_acc: 0.8269
#
# Epoch 00018: val_acc improved from 0.77120 to 0.82690, saving model to /content/saved_models/cifar10_ResNet20v2_model.018_Ch16.h5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0006313083.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.6197 - acc: 0.8468 - val_loss: 0.6399 - val_acc: 0.8399
#
# Epoch 00019: val_acc improved from 0.82690 to 0.83990, saving model to /content/saved_models/cifar10_ResNet20v2_model.019_Ch16.h5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0006093121.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.6006 - acc: 0.8514 - val_loss: 0.7008 - val_acc: 0.8179
#
# Epoch 00020: val_acc did not improve from 0.83990
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0005870059.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.5962 - acc: 0.8516 - val_loss: 0.6979 - val_acc: 0.8188
#
# Epoch 00021: val_acc did not improve from 0.83990
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0005644831.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.5804 - acc: 0.8564 - val_loss: 0.6545 - val_acc: 0.8392
#
# Epoch 00022: val_acc did not improve from 0.83990
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0004334676.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.5474 - acc: 0.8655 - val_loss: 0.6516 - val_acc: 0.8380
#
# Epoch 00023: val_acc did not improve from 0.83990
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0004153182.
# 782/782 [==============================] - 54s 69ms/step - loss: 0.5354 - acc: 0.8698 - val_loss: 0.6340 - val_acc: 0.8456
#
# Epoch 00024: val_acc improved from 0.83990 to 0.84560, saving model to /content/saved_models/cifar10_ResNet20v2_model.024_Ch16.h5
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003972056.
# 782/782 [==============================] - 54s 69ms/step - loss: 0.5182 - acc: 0.8747 - val_loss: 0.8077 - val_acc: 0.7986
#
# Epoch 00025: val_acc did not improve from 0.84560
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003791939.
# 782/782 [==============================] - 54s 69ms/step - loss: 0.5099 - acc: 0.8755 - val_loss: 0.6266 - val_acc: 0.8471
#
# Epoch 00026: val_acc improved from 0.84560 to 0.84710, saving model to /content/saved_models/cifar10_ResNet20v2_model.026_Ch16.h5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003613435.
# 782/782 [==============================] - 54s 68ms/step - loss: 0.5026 - acc: 0.8793 - val_loss: 0.6661 - val_acc: 0.8419
#
# Epoch 00027: val_acc did not improve from 0.84710
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003437111.
# 782/782 [==============================] - 54s 69ms/step - loss: 0.4879 - acc: 0.8822 - val_loss: 0.5564 - val_acc: 0.8664
#
# Epoch 00028: val_acc improved from 0.84710 to 0.86640, saving model to /content/saved_models/cifar10_ResNet20v2_model.028_Ch16.h5
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0003263493.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.4749 - acc: 0.8868 - val_loss: 0.7115 - val_acc: 0.8284
#
# Epoch 00029: val_acc did not improve from 0.86640
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0003093065.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.4703 - acc: 0.8874 - val_loss: 0.5772 - val_acc: 0.8633
#
# Epoch 00030: val_acc did not improve from 0.86640
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002926268.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.4556 - acc: 0.8931 - val_loss: 0.6530 - val_acc: 0.8416
#
# Epoch 00031: val_acc did not improve from 0.86640
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002210798.
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4404 - acc: 0.8987 - val_loss: 0.5220 - val_acc: 0.8766
#
# Epoch 00032: val_acc improved from 0.86640 to 0.87660, saving model to /content/saved_models/cifar10_ResNet20v2_model.032_Ch16.h5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0002084086.
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4308 - acc: 0.9013 - val_loss: 0.5845 - val_acc: 0.8613
#
# Epoch 00033: val_acc did not improve from 0.87660
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0001961124.
# 782/782 [==============================] - 52s 67ms/step - loss: 0.4184 - acc: 0.9047 - val_loss: 0.5164 - val_acc: 0.8796
#
# Epoch 00034: val_acc improved from 0.87660 to 0.87960, saving model to /content/saved_models/cifar10_ResNet20v2_model.034_Ch16.h5
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0001842123.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.4142 - acc: 0.9035 - val_loss: 0.5018 - val_acc: 0.8825
#
# Epoch 00035: val_acc improved from 0.87960 to 0.88250, saving model to /content/saved_models/cifar10_ResNet20v2_model.035_Ch16.h5
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.000172726.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.4052 - acc: 0.9079 - val_loss: 0.5039 - val_acc: 0.8842
#
# Epoch 00036: val_acc improved from 0.88250 to 0.88420, saving model to /content/saved_models/cifar10_ResNet20v2_model.036_Ch16.h5
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0001616679.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3997 - acc: 0.9088 - val_loss: 0.5207 - val_acc: 0.8723
#
# Epoch 00037: val_acc did not improve from 0.88420
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0001510491.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3912 - acc: 0.9111 - val_loss: 0.4877 - val_acc: 0.8825
#
# Epoch 00038: val_acc did not improve from 0.88420
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001408777.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3876 - acc: 0.9123 - val_loss: 0.4975 - val_acc: 0.8830
#
# Epoch 00039: val_acc did not improve from 0.88420
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0001311588.
# 782/782 [==============================] - 53s 67ms/step - loss: 0.3770 - acc: 0.9156 - val_loss: 0.5043 - val_acc: 0.8817
#
# Epoch 00040: val_acc did not improve from 0.88420
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0001218948.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3753 - acc: 0.9163 - val_loss: 0.5217 - val_acc: 0.8766
#
# Epoch 00041: val_acc did not improve from 0.88420
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 9.04684e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3653 - acc: 0.9199 - val_loss: 0.5125 - val_acc: 0.8803
#
# Epoch 00042: val_acc did not improve from 0.88420
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 8.37826e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3605 - acc: 0.9195 - val_loss: 0.4698 - val_acc: 0.8918
#
# Epoch 00043: val_acc improved from 0.88420 to 0.89180, saving model to /content/saved_models/cifar10_ResNet20v2_model.043_Ch16.h5
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 7.74546e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3547 - acc: 0.9235 - val_loss: 0.4851 - val_acc: 0.8882
#
# Epoch 00044: val_acc did not improve from 0.89180
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 7.1479e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3475 - acc: 0.9238 - val_loss: 0.5110 - val_acc: 0.8808
#
# Epoch 00045: val_acc did not improve from 0.89180
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 6.58489e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3460 - acc: 0.9253 - val_loss: 0.4641 - val_acc: 0.8927
#
# Epoch 00046: val_acc improved from 0.89180 to 0.89270, saving model to /content/saved_models/cifar10_ResNet20v2_model.046_Ch16.h5
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 6.05563e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3420 - acc: 0.9264 - val_loss: 0.4933 - val_acc: 0.8872
#
# Epoch 00047: val_acc did not improve from 0.89270
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 5.55919e-05.
# 782/782 [==============================] - 54s 68ms/step - loss: 0.3395 - acc: 0.9272 - val_loss: 0.4833 - val_acc: 0.8889
#
# Epoch 00048: val_acc did not improve from 0.89270
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 5.09457e-05.
# 782/782 [==============================] - 54s 69ms/step - loss: 0.3364 - acc: 0.9284 - val_loss: 0.4789 - val_acc: 0.8900
#
# Epoch 00049: val_acc did not improve from 0.89270
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 3.72853e-05.
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3300 - acc: 0.9301 - val_loss: 0.4717 - val_acc: 0.8895
#
# Epoch 00050: val_acc did not improve from 0.89270
# 10000/10000 [==============================] - 3s 292us/step
# Test loss: 0.47171098313331605
# Test accuracy: 0.8895

# %%
#load the model to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
best_model=!ls /content/saved_models/*Ch16* |tail -1
best_model[0]
# Out:
# '/content/saved_models/cifar10_ResNet20v2_model.046_Ch16.h5'

# %%
# !cp /content/saved_models/cifar10_ResNet20v2_model.046_Ch16.h5 /content/drive/My\ Drive/Colab\ Notebooks/cifar10_ResNet20v2_model.046_Ch16.h5
# !ls -lrt /content/drive/My\ Drive/Colab\ Notebooks/
# Out:
# total 34809
# drwx------ 2 root root     4096 Nov 12 09:48  Arhcive-EIP3
# -rw------- 1 root root     2203 Nov 13 06:01  README.md
# -rw------- 1 root root   203927 Nov 13 07:28 '1st DNN.ipynb'
# -rw------- 1 root root    26452 Nov 19 08:54  9th_DNN_a.ipynb
# -rw------- 1 root root    23555 Nov 19 10:08 '9th DNN.ipynb'
# -rw------- 1 root root   188063 Nov 25 21:35 'Assignment 6.ipynb'
# -rw------- 1 root root 27520024 Dec  7 11:24  Ch32_Cifar10_Resnet20v2_Best.h5
# -rw------- 1 root root   500035 Dec  7 12:41 'Copy of Assignment 4_Resnet18_cifar10.ipynb'
# -rw------- 1 root root  7173368 Dec  7 12:41  cifar10_ResNet20v2_model.046_Ch16.h5

# %%
#load the pretrained model
# !ls /content/drive/My\ Drive/Colab\ Notebooks/
model.load_weights('/content/drive/My Drive/Colab Notebooks/cifar10_ResNet20v2_model.046_Ch16.h5')
# Out:
# '1st DNN.ipynb'        Ch32_Cifar10_Resnet20v2_Best.h5
#  9th_DNN_a.ipynb       cifar10_ResNet20v2_model.046_Ch16.h5
# '9th DNN.ipynb'       'Copy of Assignment 4_Resnet18_cifar10.ipynb'
#  Arhcive-EIP3	       README.md
# 'Assignment 6.ipynb'

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255
x_test_pr = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test_pr -= x_train_mean
y_pred = model.predict(x_test_pr)

# %%
y_pred
pred_idx = y_pred.argmax(1)
pred_idx

eval=y_test[:,0] == pred_idx
#print(eval)
sum(eval)
# Out:
# 8927

# %%
last_conv_layer=[i.get_config() for i in model.layers if 'conv2d' in i.get_config()['name']][-1]
print('Last Conv Layer Name : ', last_conv_layer)
last_conv_layer_name = last_conv_layer['name']
last_conv_layer_filters = last_conv_layer['filters']
last_conv_layer = model.get_layer(last_conv_layer_name)
print('Last Conv Layer Name : ', last_conv_layer_name)
print('Last Conv Layer Filters : ', last_conv_layer_filters)
# Out:
# Last Conv Layer Name :  {'name': 'conv2d_44', 'trainable': True, 'dtype': 'float32', 'filters': 256, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'normal', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': {'class_name': 'L1L2', 'config': {'l1': 0.0, 'l2': 9.999999747378752e-05}}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Last Conv Layer Name :  conv2d_44
# Last Conv Layer Filters :  256

# %%
import matplotlib.pyplot as plt
import cv2
nums_gradcam=20
classes =['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

idxs=np.random.randint(low=1, high=y_test.shape[0], size=nums_gradcam)


for idx_ch in idxs:
  x=np.copy(x_test_pr[idx_ch])
  x = np.expand_dims(x, axis=0)
  class_idx=pred_idx[idx_ch]
  #print(class_idx)
  class_output = model.output[:, class_idx]
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(last_conv_layer_filters):
    conv_layer_output_value[:, :, i] *= (pooled_grads_value[i])
  heatmap = np.mean(conv_layer_output_value, axis = -1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap + 1e-6)
  heatmap = cv2.resize(heatmap, (x_test[idx_ch].shape[1], x_test[idx_ch].shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = x_test[idx_ch]* 0.5 +  heatmap* 0.5
  superimposed_img /=255
  fig,ax = plt.subplots(1,2)
  ax[0].set_title('Index position : {} \nTest Label : {}, \nPred label : {}'.format(idx_ch,classes[y_test[idx_ch][0]],classes[pred_idx[idx_ch]]))
  ax[1].set_title('Gradcam')
  ax[0].imshow(x_test[idx_ch])
  ax[1].imshow(superimposed_img)
