# %% [markdown]
# <a href="https://colab.research.google.com/github/bikash-bhoi/EIP4/blob/master/Session4%20Assignment/Assignment_4_Resnet18_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Training parameters
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# %%
# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch,lr):
    return  max(round(lr * 1/(1 + 0.0051 * epoch), 10),0.0001)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = GlobalAveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    #y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy'])
model.summary()
print(model_type)
print(depth)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 16)   448         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 16)   64          conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 16)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   272         activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 16)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   2320        activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 16)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 64)   1088        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 64)   1088        activation_60[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           conv2d_71[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 64)   256         add_19[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 64)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 16)   1040        activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 16)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 16)   2320        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 16)   64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 16)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 64)   1088        activation_63[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           add_19[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 64)   256         add_20[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 64)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 64)   4160        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 16, 16, 64)   256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16, 16, 64)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 64)   36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 16, 16, 64)   256         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 64)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 128)  8320        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 128)  8320        activation_66[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 128)  0           conv2d_78[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 128)  512         add_21[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 128)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 64)   8256        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   36928       activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 64)   256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 128)  8320        activation_69[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 128)  0           add_21[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 128)  512         add_22[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 16, 128)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 128)    16512       activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 128)    512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 128)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 128)    147584      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 128)    512         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 8, 8, 128)    0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 256)    33024       add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 256)    33024       activation_72[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 8, 256)    0           conv2d_85[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 8, 8, 256)    1024        add_23[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 8, 8, 256)    0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 128)    32896       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 8, 8, 128)    512         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 8, 8, 128)    0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 128)    147584      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 128)    512         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 128)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 256)    33024       activation_75[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 256)    0           add_23[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 256)    1024        add_24[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 256)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           activation_76[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2
# 20

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)
# Out:
# /content/saved_models/cifar10_ResNet20v2_model.{epoch:03d}.h5

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule,verbose=1)

lr_reducer = ReduceLROnPlateau(factor=0.4,
                               cooldown=0,
                               patience=3,
                               monitor='val_loss',
                               min_lr=0.3e-5)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=15,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.1,
        # set range for random zoom
        zoom_range=0.1,
        # set range for random channel shifts
        channel_shift_range=0.1,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 782/782 [==============================] - 60s 76ms/step - loss: 1.8134 - acc: 0.4709 - val_loss: 1.5881 - val_acc: 0.5439
#
# Epoch 00001: val_acc improved from -inf to 0.54390, saving model to /content/saved_models/cifar10_ResNet20v2_model.001.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0009949259.
# 782/782 [==============================] - 49s 63ms/step - loss: 1.3908 - acc: 0.6100 - val_loss: 1.8540 - val_acc: 0.5060
#
# Epoch 00002: val_acc did not improve from 0.54390
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0009848801.
# 782/782 [==============================] - 50s 64ms/step - loss: 1.2162 - acc: 0.6640 - val_loss: 1.3225 - val_acc: 0.6358
#
# Epoch 00003: val_acc improved from 0.54390 to 0.63580, saving model to /content/saved_models/cifar10_ResNet20v2_model.003.h5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0009700386.
# 782/782 [==============================] - 49s 63ms/step - loss: 1.1074 - acc: 0.7008 - val_loss: 1.1578 - val_acc: 0.6871
#
# Epoch 00004: val_acc improved from 0.63580 to 0.68710, saving model to /content/saved_models/cifar10_ResNet20v2_model.004.h5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0009506454.
# 782/782 [==============================] - 50s 63ms/step - loss: 1.0254 - acc: 0.7278 - val_loss: 1.0289 - val_acc: 0.7313
#
# Epoch 00005: val_acc improved from 0.68710 to 0.73130, saving model to /content/saved_models/cifar10_ResNet20v2_model.005.h5
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0009270068.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.9672 - acc: 0.7449 - val_loss: 1.3412 - val_acc: 0.6568
#
# Epoch 00006: val_acc did not improve from 0.73130
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0008994827.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.9179 - acc: 0.7609 - val_loss: 0.9339 - val_acc: 0.7641
#
# Epoch 00007: val_acc improved from 0.73130 to 0.76410, saving model to /content/saved_models/cifar10_ResNet20v2_model.007.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.000868478.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.8712 - acc: 0.7753 - val_loss: 1.1610 - val_acc: 0.7046
#
# Epoch 00008: val_acc did not improve from 0.76410
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008344331.
# 782/782 [==============================] - 50s 63ms/step - loss: 0.8357 - acc: 0.7863 - val_loss: 1.2100 - val_acc: 0.7111
#
# Epoch 00009: val_acc did not improve from 0.76410
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007978135.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.8116 - acc: 0.7952 - val_loss: 1.0073 - val_acc: 0.7472
#
# Epoch 00010: val_acc did not improve from 0.76410
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0003036398.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.7057 - acc: 0.8280 - val_loss: 0.7733 - val_acc: 0.8117
#
# Epoch 00011: val_acc improved from 0.76410 to 0.81170, saving model to /content/saved_models/cifar10_ResNet20v2_model.011.h5
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0002875105.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.6732 - acc: 0.8394 - val_loss: 0.7777 - val_acc: 0.8091
#
# Epoch 00012: val_acc did not improve from 0.81170
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0002709296.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.6508 - acc: 0.8460 - val_loss: 0.7253 - val_acc: 0.8238
#
# Epoch 00013: val_acc improved from 0.81170 to 0.82380, saving model to /content/saved_models/cifar10_ResNet20v2_model.013.h5
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0002540838.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.6277 - acc: 0.8499 - val_loss: 0.7423 - val_acc: 0.8150
#
# Epoch 00014: val_acc did not improve from 0.82380
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0002371512.
# 782/782 [==============================] - 50s 63ms/step - loss: 0.6098 - acc: 0.8554 - val_loss: 0.6883 - val_acc: 0.8313
#
# Epoch 00015: val_acc improved from 0.82380 to 0.83130, saving model to /content/saved_models/cifar10_ResNet20v2_model.015.h5
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0002202984.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5967 - acc: 0.8582 - val_loss: 0.7029 - val_acc: 0.8269
#
# Epoch 00016: val_acc did not improve from 0.83130
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0002036783.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5787 - acc: 0.8644 - val_loss: 0.6418 - val_acc: 0.8478
#
# Epoch 00017: val_acc improved from 0.83130 to 0.84780, saving model to /content/saved_models/cifar10_ResNet20v2_model.017.h5
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001874283.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.5670 - acc: 0.8665 - val_loss: 0.6948 - val_acc: 0.8344
#
# Epoch 00018: val_acc did not improve from 0.84780
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001716691.
# 782/782 [==============================] - 50s 63ms/step - loss: 0.5525 - acc: 0.8706 - val_loss: 0.6428 - val_acc: 0.8439
#
# Epoch 00019: val_acc did not improve from 0.84780
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001565039.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5391 - acc: 0.8759 - val_loss: 0.5897 - val_acc: 0.8643
#
# Epoch 00020: val_acc improved from 0.84780 to 0.86430, saving model to /content/saved_models/cifar10_ResNet20v2_model.020.h5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001420181.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.5291 - acc: 0.8785 - val_loss: 0.6357 - val_acc: 0.8438
#
# Epoch 00021: val_acc did not improve from 0.86430
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001282794.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5184 - acc: 0.8810 - val_loss: 0.5919 - val_acc: 0.8581
#
# Epoch 00022: val_acc did not improve from 0.86430
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0001153384.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5052 - acc: 0.8840 - val_loss: 0.6146 - val_acc: 0.8533
#
# Epoch 00023: val_acc did not improve from 0.86430
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4954 - acc: 0.8869 - val_loss: 0.5950 - val_acc: 0.8591
#
# Epoch 00024: val_acc did not improve from 0.86430
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 50s 63ms/step - loss: 0.4852 - acc: 0.8917 - val_loss: 0.6070 - val_acc: 0.8590
#
# Epoch 00025: val_acc did not improve from 0.86430
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4824 - acc: 0.8923 - val_loss: 0.6199 - val_acc: 0.8548
#
# Epoch 00026: val_acc did not improve from 0.86430
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4793 - acc: 0.8909 - val_loss: 0.6406 - val_acc: 0.8471
#
# Epoch 00027: val_acc did not improve from 0.86430
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 50s 63ms/step - loss: 0.4752 - acc: 0.8925 - val_loss: 0.5956 - val_acc: 0.8613
#
# Epoch 00028: val_acc did not improve from 0.86430
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4641 - acc: 0.8961 - val_loss: 0.6197 - val_acc: 0.8533
#
# Epoch 00029: val_acc did not improve from 0.86430
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4674 - acc: 0.8969 - val_loss: 0.5969 - val_acc: 0.8595
#
# Epoch 00030: val_acc did not improve from 0.86430
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4636 - acc: 0.8945 - val_loss: 0.6028 - val_acc: 0.8582
#
# Epoch 00031: val_acc did not improve from 0.86430
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4561 - acc: 0.8989 - val_loss: 0.5958 - val_acc: 0.8611
#
# Epoch 00032: val_acc did not improve from 0.86430
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4442 - acc: 0.9013 - val_loss: 0.5894 - val_acc: 0.8597
#
# Epoch 00033: val_acc did not improve from 0.86430
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.4461 - acc: 0.9023 - val_loss: 0.6161 - val_acc: 0.8527
#
# Epoch 00034: val_acc did not improve from 0.86430
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4432 - acc: 0.9017 - val_loss: 0.5778 - val_acc: 0.8618
#
# Epoch 00035: val_acc did not improve from 0.86430
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4389 - acc: 0.9028 - val_loss: 0.5600 - val_acc: 0.8719
#
# Epoch 00036: val_acc improved from 0.86430 to 0.87190, saving model to /content/saved_models/cifar10_ResNet20v2_model.036.h5
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4304 - acc: 0.9058 - val_loss: 0.5821 - val_acc: 0.8620
#
# Epoch 00037: val_acc did not improve from 0.87190
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4310 - acc: 0.9050 - val_loss: 0.6406 - val_acc: 0.8504
#
# Epoch 00038: val_acc did not improve from 0.87190
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4286 - acc: 0.9055 - val_loss: 0.6055 - val_acc: 0.8585
#
# Epoch 00039: val_acc did not improve from 0.87190
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4250 - acc: 0.9067 - val_loss: 0.5621 - val_acc: 0.8681
#
# Epoch 00040: val_acc did not improve from 0.87190
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.4177 - acc: 0.9085 - val_loss: 0.6489 - val_acc: 0.8493
#
# Epoch 00041: val_acc did not improve from 0.87190
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4196 - acc: 0.9074 - val_loss: 0.5502 - val_acc: 0.8737
#
# Epoch 00042: val_acc improved from 0.87190 to 0.87370, saving model to /content/saved_models/cifar10_ResNet20v2_model.042.h5
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4159 - acc: 0.9091 - val_loss: 0.5609 - val_acc: 0.8693
#
# Epoch 00043: val_acc did not improve from 0.87370
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4124 - acc: 0.9094 - val_loss: 0.5372 - val_acc: 0.8745
#
# Epoch 00044: val_acc improved from 0.87370 to 0.87450, saving model to /content/saved_models/cifar10_ResNet20v2_model.044.h5
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4076 - acc: 0.9110 - val_loss: 0.5658 - val_acc: 0.8680
#
# Epoch 00045: val_acc did not improve from 0.87450
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4017 - acc: 0.9139 - val_loss: 0.6248 - val_acc: 0.8548
#
# Epoch 00046: val_acc did not improve from 0.87450
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.3993 - acc: 0.9135 - val_loss: 0.5727 - val_acc: 0.8658
#
# Epoch 00047: val_acc did not improve from 0.87450
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.3972 - acc: 0.9137 - val_loss: 0.5962 - val_acc: 0.8596
#
# Epoch 00048: val_acc did not improve from 0.87450
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.3961 - acc: 0.9141 - val_loss: 0.5505 - val_acc: 0.8723
#
# Epoch 00049: val_acc did not improve from 0.87450
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.0001.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.3897 - acc: 0.9159 - val_loss: 0.5795 - val_acc: 0.8660
#
# Epoch 00050: val_acc did not improve from 0.87450
# 10000/10000 [==============================] - 2s 181us/step
# Test loss: 0.5794890902042389
# Test accuracy: 0.866
