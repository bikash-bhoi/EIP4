# %% [markdown]
# <a href="https://colab.research.google.com/github/bikash-bhoi/EIP4/blob/master/Session4%20Assignment/Assignment_4_Resnet18_cifar10_cutout_Gradcam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):

  """
  p : the probability that random erasing is performed
  s_l, s_h : minimum / maximum proportion of erased area against input image
  r_1, r_2 : minimum / maximum aspect ratio of erased area
  v_l, v_h : minimum / maximum value for erased area
  pixel_level : pixel-level randomization for erased area
  """

  def eraser(input_img):
    img_h, img_w, img_c = input_img.shape
    p_1 = np.random.rand()

    if p_1 > p:
        return input_img

    while True:
        s = np.random.uniform(s_l, s_h) * img_h * img_w
        r = np.random.uniform(r_1, r_2)
        w = int(np.sqrt(s / r))
        h = int(np.sqrt(s * r))
        left = np.random.randint(0, img_w)
        top = np.random.randint(0, img_h)

        if left + w <= img_w and top + h <= img_h:
            break

    if pixel_level:
        c = np.random.uniform(v_l, v_h, (h, w, img_c))
    else:
        c = np.random.uniform(v_l, v_h)

    input_img[top:top + h, left:left + w, :] = c

    return input_img

  return eraser

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = GlobalAveragePooling2D()(x)
    #y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    #y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.002),
              metrics=['accuracy'])
model.summary()
print(model_type)
print(depth)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 16)   272         activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 64)   1088        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   1088        activation_41[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 64)   0           conv2d_49[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 16)   1040        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 16)   64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 16)   64          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 64)   1088        activation_44[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 64)   0           add_13[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 64)   4160        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 64)   256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 64)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 64)   256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 128)  8320        add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 128)  8320        activation_47[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 128)  0           conv2d_56[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 128)  512         add_15[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 64)   8256        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 64)   256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 64)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 64)   36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 64)   256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 64)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 128)  8320        activation_50[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 16, 16, 128)  0           add_15[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 128)  512         add_16[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 128)    16512       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 128)    512         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 128)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 128)    147584      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 256)    33024       add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 256)    33024       activation_53[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           conv2d_63[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 256)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 8, 8, 128)    32896       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 128)    512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 128)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 8, 8, 128)    147584      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 128)    512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 128)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 256)    33024       activation_56[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           add_17[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 256)    1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 256)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           activation_57[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           2570        global_average_pooling2d_3[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2
# 20

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)
# Out:
# /content/saved_models/cifar10_ResNet20v2_model.{epoch:03d}.h5

# %%
#Define LR Scheduler
def lr_schedule(epoch,lr):
    return round(lr * 1/(1 + 0.0021 * epoch), 10)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule,verbose=1)

lr_reducer = ReduceLROnPlateau(factor=0.8,
                               cooldown=0,
                               patience=3,
                               monitor='val_loss',
                               min_lr=0.3e-5)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=15,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.1,
        # set range for random zoom
        zoom_range=0.1,
        # set range for random channel shifts
        channel_shift_range=0.1,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        #Cutout Implementation
        preprocessing_function=get_random_eraser(p=0.2,v_l=0, v_h=1, s_l=0.008, s_h=0.1, pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0020000001.
# 391/391 [==============================] - 86s 221ms/step - loss: 1.7889 - acc: 0.4742 - val_loss: 1.8972 - val_acc: 0.4949
#
# Epoch 00001: val_acc improved from -inf to 0.49490, saving model to /content/saved_models/cifar10_ResNet20v2_model.001.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0019958089.
# 391/391 [==============================] - 76s 193ms/step - loss: 1.3834 - acc: 0.6007 - val_loss: 1.7352 - val_acc: 0.4999
#
# Epoch 00002: val_acc improved from 0.49490 to 0.49990, saving model to /content/saved_models/cifar10_ResNet20v2_model.002.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0019874616.
# 391/391 [==============================] - 75s 191ms/step - loss: 1.2212 - acc: 0.6536 - val_loss: 1.3788 - val_acc: 0.6334
#
# Epoch 00003: val_acc improved from 0.49990 to 0.63340, saving model to /content/saved_models/cifar10_ResNet20v2_model.003.h5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0019750191.
# 391/391 [==============================] - 74s 190ms/step - loss: 1.1198 - acc: 0.6880 - val_loss: 1.2209 - val_acc: 0.6627
#
# Epoch 00004: val_acc improved from 0.63340 to 0.66270, saving model to /content/saved_models/cifar10_ResNet20v2_model.004.h5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001958567.
# 391/391 [==============================] - 75s 192ms/step - loss: 1.0493 - acc: 0.7132 - val_loss: 1.3066 - val_acc: 0.6433
#
# Epoch 00005: val_acc did not improve from 0.66270
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0019382157.
# 391/391 [==============================] - 74s 190ms/step - loss: 0.9916 - acc: 0.7317 - val_loss: 1.4201 - val_acc: 0.5991
#
# Epoch 00006: val_acc did not improve from 0.66270
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0019140981.
# 391/391 [==============================] - 76s 193ms/step - loss: 0.9508 - acc: 0.7463 - val_loss: 1.5354 - val_acc: 0.6047
#
# Epoch 00007: val_acc did not improve from 0.66270
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0015090948.
# 391/391 [==============================] - 75s 193ms/step - loss: 0.8836 - acc: 0.7667 - val_loss: 1.1847 - val_acc: 0.6881
#
# Epoch 00008: val_acc improved from 0.66270 to 0.68810, saving model to /content/saved_models/cifar10_ResNet20v2_model.008.h5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0014841609.
# 391/391 [==============================] - 74s 190ms/step - loss: 0.8528 - acc: 0.7755 - val_loss: 1.0860 - val_acc: 0.6998
#
# Epoch 00009: val_acc improved from 0.68810 to 0.69980, saving model to /content/saved_models/cifar10_ResNet20v2_model.009.h5
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0014566306.
# 391/391 [==============================] - 74s 189ms/step - loss: 0.8274 - acc: 0.7848 - val_loss: 0.9065 - val_acc: 0.7601
#
# Epoch 00010: val_acc improved from 0.69980 to 0.76010, saving model to /content/saved_models/cifar10_ResNet20v2_model.010.h5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0014266706.
# 391/391 [==============================] - 73s 186ms/step - loss: 0.7957 - acc: 0.7950 - val_loss: 0.9005 - val_acc: 0.7620
#
# Epoch 00011: val_acc improved from 0.76010 to 0.76200, saving model to /content/saved_models/cifar10_ResNet20v2_model.011.h5
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0013944586.
# 391/391 [==============================] - 73s 187ms/step - loss: 0.7780 - acc: 0.8014 - val_loss: 0.8815 - val_acc: 0.7750
#
# Epoch 00012: val_acc improved from 0.76200 to 0.77500, saving model to /content/saved_models/cifar10_ResNet20v2_model.012.h5
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001360182.
# 391/391 [==============================] - 74s 190ms/step - loss: 0.7614 - acc: 0.8072 - val_loss: 0.8910 - val_acc: 0.7622
#
# Epoch 00013: val_acc did not improve from 0.77500
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0013240358.
# 391/391 [==============================] - 73s 187ms/step - loss: 0.7397 - acc: 0.8121 - val_loss: 1.1617 - val_acc: 0.7065
#
# Epoch 00014: val_acc did not improve from 0.77500
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0012862209.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.7219 - acc: 0.8189 - val_loss: 1.0888 - val_acc: 0.7334
#
# Epoch 00015: val_acc did not improve from 0.77500
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0009975537.
# 391/391 [==============================] - 76s 195ms/step - loss: 0.6756 - acc: 0.8330 - val_loss: 0.7878 - val_acc: 0.8049
#
# Epoch 00016: val_acc improved from 0.77500 to 0.80490, saving model to /content/saved_models/cifar10_ResNet20v2_model.016.h5
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0009651255.
# 391/391 [==============================] - 76s 193ms/step - loss: 0.6601 - acc: 0.8375 - val_loss: 0.8809 - val_acc: 0.7800
#
# Epoch 00017: val_acc did not improve from 0.80490
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0009318582.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.6420 - acc: 0.8410 - val_loss: 0.7464 - val_acc: 0.8080
#
# Epoch 00018: val_acc improved from 0.80490 to 0.80800, saving model to /content/saved_models/cifar10_ResNet20v2_model.018.h5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0008979169.
# 391/391 [==============================] - 76s 194ms/step - loss: 0.6267 - acc: 0.8465 - val_loss: 0.9485 - val_acc: 0.7497
#
# Epoch 00019: val_acc did not improve from 0.80800
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0008634647.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.6100 - acc: 0.8509 - val_loss: 0.6921 - val_acc: 0.8287
#
# Epoch 00020: val_acc improved from 0.80800 to 0.82870, saving model to /content/saved_models/cifar10_ResNet20v2_model.020.h5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.000828661.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.5936 - acc: 0.8558 - val_loss: 0.8012 - val_acc: 0.7929
#
# Epoch 00021: val_acc did not improve from 0.82870
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0007936606.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.5839 - acc: 0.8581 - val_loss: 0.7561 - val_acc: 0.8189
#
# Epoch 00022: val_acc did not improve from 0.82870
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0007586127.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.5673 - acc: 0.8617 - val_loss: 1.2084 - val_acc: 0.7296
#
# Epoch 00023: val_acc did not improve from 0.82870
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.000578928.
# 391/391 [==============================] - 76s 195ms/step - loss: 0.5361 - acc: 0.8732 - val_loss: 0.7531 - val_acc: 0.8151
#
# Epoch 00024: val_acc did not improve from 0.82870
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.00055115.
# 391/391 [==============================] - 76s 195ms/step - loss: 0.5216 - acc: 0.8789 - val_loss: 0.6036 - val_acc: 0.8536
#
# Epoch 00025: val_acc improved from 0.82870 to 0.85360, saving model to /content/saved_models/cifar10_ResNet20v2_model.025.h5
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.000523658.
# 391/391 [==============================] - 76s 194ms/step - loss: 0.5100 - acc: 0.8802 - val_loss: 0.5643 - val_acc: 0.8675
#
# Epoch 00026: val_acc improved from 0.85360 to 0.86750, saving model to /content/saved_models/cifar10_ResNet20v2_model.026.h5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0004965466.
# 391/391 [==============================] - 76s 194ms/step - loss: 0.5001 - acc: 0.8833 - val_loss: 0.5875 - val_acc: 0.8602
#
# Epoch 00027: val_acc did not improve from 0.86750
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0004699031.
# 391/391 [==============================] - 76s 194ms/step - loss: 0.4872 - acc: 0.8851 - val_loss: 0.6122 - val_acc: 0.8530
#
# Epoch 00028: val_acc did not improve from 0.86750
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0004438072.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.4733 - acc: 0.8897 - val_loss: 0.6291 - val_acc: 0.8466
#
# Epoch 00029: val_acc did not improve from 0.86750
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0003346647.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.4502 - acc: 0.8969 - val_loss: 0.6518 - val_acc: 0.8409
#
# Epoch 00030: val_acc did not improve from 0.86750
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0003148304.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.4391 - acc: 0.9007 - val_loss: 0.5580 - val_acc: 0.8684
#
# Epoch 00031: val_acc improved from 0.86750 to 0.86840, saving model to /content/saved_models/cifar10_ResNet20v2_model.031.h5
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002955876.
# 391/391 [==============================] - 77s 197ms/step - loss: 0.4284 - acc: 0.9039 - val_loss: 0.5995 - val_acc: 0.8523
#
# Epoch 00032: val_acc did not improve from 0.86840
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0002769749.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.4211 - acc: 0.9046 - val_loss: 0.5418 - val_acc: 0.8724
#
# Epoch 00033: val_acc improved from 0.86840 to 0.87240, saving model to /content/saved_models/cifar10_ResNet20v2_model.033.h5
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002590245.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.4105 - acc: 0.9089 - val_loss: 0.5782 - val_acc: 0.8673
#
# Epoch 00034: val_acc did not improve from 0.87240
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0002417626.
# 391/391 [==============================] - 76s 194ms/step - loss: 0.4066 - acc: 0.9098 - val_loss: 0.5202 - val_acc: 0.8797
#
# Epoch 00035: val_acc improved from 0.87240 to 0.87970, saving model to /content/saved_models/cifar10_ResNet20v2_model.035.h5
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002252097.
# 391/391 [==============================] - 78s 200ms/step - loss: 0.3982 - acc: 0.9130 - val_loss: 0.5207 - val_acc: 0.8787
#
# Epoch 00036: val_acc did not improve from 0.87970
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002093805.
# 391/391 [==============================] - 78s 198ms/step - loss: 0.3899 - acc: 0.9146 - val_loss: 0.5727 - val_acc: 0.8677
#
# Epoch 00037: val_acc did not improve from 0.87970
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0001942846.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.3809 - acc: 0.9178 - val_loss: 0.5411 - val_acc: 0.8750
#
# Epoch 00038: val_acc did not improve from 0.87970
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001439412.
# 391/391 [==============================] - 75s 192ms/step - loss: 0.3635 - acc: 0.9243 - val_loss: 0.5134 - val_acc: 0.8827
#
# Epoch 00039: val_acc improved from 0.87970 to 0.88270, saving model to /content/saved_models/cifar10_ResNet20v2_model.039.h5
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0001330448.
# 391/391 [==============================] - 73s 187ms/step - loss: 0.3615 - acc: 0.9235 - val_loss: 0.5356 - val_acc: 0.8773
#
# Epoch 00040: val_acc did not improve from 0.88270
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0001227351.
# 391/391 [==============================] - 75s 193ms/step - loss: 0.3545 - acc: 0.9265 - val_loss: 0.5175 - val_acc: 0.8802
#
# Epoch 00041: val_acc did not improve from 0.88270
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0001130053.
# 391/391 [==============================] - 76s 196ms/step - loss: 0.3484 - acc: 0.9275 - val_loss: 0.5400 - val_acc: 0.8750
#
# Epoch 00042: val_acc did not improve from 0.88270
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 8.30769e-05.
# 391/391 [==============================] - 76s 195ms/step - loss: 0.3418 - acc: 0.9291 - val_loss: 0.5265 - val_acc: 0.8807
#
# Epoch 00043: val_acc did not improve from 0.88270
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 7.61964e-05.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.3381 - acc: 0.9307 - val_loss: 0.4991 - val_acc: 0.8858
#
# Epoch 00044: val_acc improved from 0.88270 to 0.88580, saving model to /content/saved_models/cifar10_ResNet20v2_model.044.h5
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 6.97514e-05.
# 391/391 [==============================] - 77s 197ms/step - loss: 0.3354 - acc: 0.9311 - val_loss: 0.5256 - val_acc: 0.8823
#
# Epoch 00045: val_acc did not improve from 0.88580
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 6.3729e-05.
# 391/391 [==============================] - 77s 198ms/step - loss: 0.3314 - acc: 0.9332 - val_loss: 0.4916 - val_acc: 0.8897
#
# Epoch 00046: val_acc improved from 0.88580 to 0.88970, saving model to /content/saved_models/cifar10_ResNet20v2_model.046.h5
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 5.81151e-05.
# 391/391 [==============================] - 77s 197ms/step - loss: 0.3276 - acc: 0.9346 - val_loss: 0.5016 - val_acc: 0.8861
#
# Epoch 00047: val_acc did not improve from 0.88970
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 5.28944e-05.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.3259 - acc: 0.9346 - val_loss: 0.4802 - val_acc: 0.8930
#
# Epoch 00048: val_acc improved from 0.88970 to 0.89300, saving model to /content/saved_models/cifar10_ResNet20v2_model.048.h5
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 4.80509e-05.
# 391/391 [==============================] - 77s 197ms/step - loss: 0.3217 - acc: 0.9360 - val_loss: 0.4882 - val_acc: 0.8907
#
# Epoch 00049: val_acc did not improve from 0.89300
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 4.35678e-05.
# 391/391 [==============================] - 77s 196ms/step - loss: 0.3188 - acc: 0.9369 - val_loss: 0.4895 - val_acc: 0.8910
#
# Epoch 00050: val_acc did not improve from 0.89300
# 10000/10000 [==============================] - 5s 477us/step
# Test loss: 0.4894509957790375
# Test accuracy: 0.891

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_pred = model.predict(x_test)

# %%
y_pred
pred_idx = y_pred.argmax(1)
pred_idx
# Out:
# array([1, 9, 1, ..., 9, 9, 9])

# %%
last_conv_layer_name=[i.get_config()['name'] for i in model.layers if 'conv2d' in i.get_config()['name']][-1]
print('Last Conv Layer Name : ', last_conv_layer_name)
last_conv_layer = model.get_layer(last_conv_layer_name)
# Out:
# Last Conv Layer Name :  conv2d_66

# %%
import matplotlib.pyplot as plt
import cv2
nums_gradcam=15
classes =['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

idxs=np.random.randint(low=1, high=y_test.shape[0], size=nums_gradcam)


for idx_ch in idxs:
  x=np.copy(x_test[idx_ch])
  x = np.expand_dims(x, axis=0)
  class_idx=pred_idx[idx_ch]
  #print(class_idx)
  class_output = model.output[:, class_idx]
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(128):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  heatmap = np.mean(conv_layer_output_value, axis = -1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  heatmap = cv2.resize(heatmap, (x_test[idx_ch].shape[1], x_test[idx_ch].shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = x_test[idx_ch]* 0.5 +  heatmap* 0.5
  superimposed_img /=255
  fig,ax = plt.subplots(1,2)
  ax[0].set_title('Image')
  ax[1].set_title('Gradcam')
  ax[0].imshow(x_test[idx_ch])
  ax[1].imshow(superimposed_img)
