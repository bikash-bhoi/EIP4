# %% [markdown]
# <a href="https://colab.research.google.com/github/bikash-bhoi/EIP4/blob/master/Session4/Assignment_4_Resnet18_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
# Training parameters
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# %%
# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch,lr):
    return round(lr * 1/(1 + 0.0051 * epoch), 10)

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy'])
model.summary()
print(model_type)
print(depth)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 32, 32, 16)   448         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 32, 32, 16)   64          conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 32, 16)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 32, 16)   272         activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 32, 32, 16)   64          conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 32, 16)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 32, 32, 16)   2320        activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 32, 32, 16)   64          conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 32, 16)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 32, 32, 64)   1088        activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 32, 32, 64)   1088        activation_98[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 32, 64)   0           conv2d_115[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 32, 32, 64)   256         add_31[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 32, 32, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 32, 32, 16)   1040        activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 32, 32, 16)   64          conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 32, 32, 16)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 32, 32, 16)   2320        activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 32, 32, 16)   64          conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 32, 32, 16)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 32, 32, 64)   1088        activation_101[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 32, 64)   0           add_31[0][0]
#                                                                  conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 32, 32, 64)   256         add_32[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 32, 32, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 64)   4160        activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 64)   256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 64)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 16, 16, 64)   36928       activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 64)   256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 64)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 16, 128)  8320        add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 16, 128)  8320        activation_104[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 16, 128)  0           conv2d_122[0][0]
#                                                                  conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 128)  512         add_33[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 128)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 16, 64)   8256        activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 64)   256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 64)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 16, 64)   36928       activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 64)   256         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 64)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 16, 128)  8320        activation_107[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 16, 16, 128)  0           add_33[0][0]
#                                                                  conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 128)  512         add_34[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 128)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 128)    16512       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 128)    512         conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 8, 8, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 128)    147584      activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 128)    512         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 8, 8, 128)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 256)    33024       add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 256)    33024       activation_110[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 256)    0           conv2d_129[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 256)    1024        add_35[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 8, 8, 256)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 128)    32896       activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 128)    512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 8, 8, 128)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 128)    147584      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 128)    512         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 8, 8, 128)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 256)    33024       activation_113[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 256)    0           add_35[0][0]
#                                                                  conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 8, 8, 256)    1024        add_36[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 8, 8, 256)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 256)    0           activation_114[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 256)          0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10)           2570        flatten_6[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2
# 20

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)
# Out:
# /content/saved_models/cifar10_ResNet20v2_model.{epoch:03d}.h5

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule,verbose=1)

lr_reducer = ReduceLROnPlateau(factor=0.4,
                               cooldown=0,
                               patience=3,
                               monitor='val_loss',
                               min_lr=0.3e-5)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=15,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.1,
        # set range for random zoom
        zoom_range=0.1,
        # set range for random channel shifts
        channel_shift_range=0.1,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 782/782 [==============================] - 59s 75ms/step - loss: 1.8099 - acc: 0.4762 - val_loss: 2.6633 - val_acc: 0.3401
#
# Epoch 00001: val_acc improved from -inf to 0.34010, saving model to /content/saved_models/cifar10_ResNet20v2_model.001.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0009949259.
# 782/782 [==============================] - 49s 62ms/step - loss: 1.3793 - acc: 0.6121 - val_loss: 1.9730 - val_acc: 0.4920
#
# Epoch 00002: val_acc improved from 0.34010 to 0.49200, saving model to /content/saved_models/cifar10_ResNet20v2_model.002.h5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0009848801.
# 782/782 [==============================] - 49s 63ms/step - loss: 1.2014 - acc: 0.6703 - val_loss: 1.2761 - val_acc: 0.6514
#
# Epoch 00003: val_acc improved from 0.49200 to 0.65140, saving model to /content/saved_models/cifar10_ResNet20v2_model.003.h5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0009700386.
# 782/782 [==============================] - 48s 62ms/step - loss: 1.0756 - acc: 0.7124 - val_loss: 1.2869 - val_acc: 0.6629
#
# Epoch 00004: val_acc improved from 0.65140 to 0.66290, saving model to /content/saved_models/cifar10_ResNet20v2_model.004.h5
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0009506454.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.9949 - acc: 0.7372 - val_loss: 1.1822 - val_acc: 0.6896
#
# Epoch 00005: val_acc improved from 0.66290 to 0.68960, saving model to /content/saved_models/cifar10_ResNet20v2_model.005.h5
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0009270068.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.9384 - acc: 0.7546 - val_loss: 1.5783 - val_acc: 0.5601
#
# Epoch 00006: val_acc did not improve from 0.68960
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0008994827.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.8860 - acc: 0.7711 - val_loss: 1.0958 - val_acc: 0.7152
#
# Epoch 00007: val_acc improved from 0.68960 to 0.71520, saving model to /content/saved_models/cifar10_ResNet20v2_model.007.h5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.000868478.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.8424 - acc: 0.7859 - val_loss: 1.0006 - val_acc: 0.7397
#
# Epoch 00008: val_acc improved from 0.71520 to 0.73970, saving model to /content/saved_models/cifar10_ResNet20v2_model.008.h5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008344331.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.8092 - acc: 0.7969 - val_loss: 0.9163 - val_acc: 0.7718
#
# Epoch 00009: val_acc improved from 0.73970 to 0.77180, saving model to /content/saved_models/cifar10_ResNet20v2_model.009.h5
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007978135.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.7758 - acc: 0.8058 - val_loss: 0.9054 - val_acc: 0.7733
#
# Epoch 00010: val_acc improved from 0.77180 to 0.77330, saving model to /content/saved_models/cifar10_ResNet20v2_model.010.h5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007590995.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.7451 - acc: 0.8145 - val_loss: 0.9175 - val_acc: 0.7555
#
# Epoch 00011: val_acc did not improve from 0.77330
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0007187762.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.7145 - acc: 0.8253 - val_loss: 0.8081 - val_acc: 0.7986
#
# Epoch 00012: val_acc improved from 0.77330 to 0.79860, saving model to /content/saved_models/cifar10_ResNet20v2_model.012.h5
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.000677324.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.6893 - acc: 0.8317 - val_loss: 0.8789 - val_acc: 0.7773
#
# Epoch 00013: val_acc did not improve from 0.79860
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0006352096.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.6726 - acc: 0.8372 - val_loss: 0.8837 - val_acc: 0.7774
#
# Epoch 00014: val_acc did not improve from 0.79860
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005928781.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.6423 - acc: 0.8458 - val_loss: 0.9672 - val_acc: 0.7536
#
# Epoch 00015: val_acc did not improve from 0.79860
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0002202984.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.5668 - acc: 0.8711 - val_loss: 0.6582 - val_acc: 0.8447
#
# Epoch 00016: val_acc improved from 0.79860 to 0.84470, saving model to /content/saved_models/cifar10_ResNet20v2_model.016.h5
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0002036783.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.5377 - acc: 0.8804 - val_loss: 0.6891 - val_acc: 0.8354
#
# Epoch 00017: val_acc did not improve from 0.84470
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001874283.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.5225 - acc: 0.8831 - val_loss: 0.6378 - val_acc: 0.8469
#
# Epoch 00018: val_acc improved from 0.84470 to 0.84690, saving model to /content/saved_models/cifar10_ResNet20v2_model.018.h5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001716691.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.5077 - acc: 0.8870 - val_loss: 0.6000 - val_acc: 0.8591
#
# Epoch 00019: val_acc improved from 0.84690 to 0.85910, saving model to /content/saved_models/cifar10_ResNet20v2_model.019.h5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001565039.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4946 - acc: 0.8916 - val_loss: 0.6085 - val_acc: 0.8550
#
# Epoch 00020: val_acc did not improve from 0.85910
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001420181.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4788 - acc: 0.8958 - val_loss: 0.6283 - val_acc: 0.8494
#
# Epoch 00021: val_acc did not improve from 0.85910
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001282794.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4650 - acc: 0.8991 - val_loss: 0.6262 - val_acc: 0.8530
#
# Epoch 00022: val_acc did not improve from 0.85910
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 4.61354e-05.
# 782/782 [==============================] - 50s 64ms/step - loss: 0.4460 - acc: 0.9062 - val_loss: 0.5692 - val_acc: 0.8664
#
# Epoch 00023: val_acc improved from 0.85910 to 0.86640, saving model to /content/saved_models/cifar10_ResNet20v2_model.023.h5
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 4.12919e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4351 - acc: 0.9093 - val_loss: 0.5513 - val_acc: 0.8727
#
# Epoch 00024: val_acc improved from 0.86640 to 0.87270, saving model to /content/saved_models/cifar10_ResNet20v2_model.024.h5
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 3.67889e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4350 - acc: 0.9098 - val_loss: 0.5664 - val_acc: 0.8691
#
# Epoch 00025: val_acc did not improve from 0.87270
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 3.26287e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4252 - acc: 0.9128 - val_loss: 0.5692 - val_acc: 0.8669
#
# Epoch 00026: val_acc did not improve from 0.87270
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 2.88087e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4295 - acc: 0.9100 - val_loss: 0.5511 - val_acc: 0.8722
#
# Epoch 00027: val_acc did not improve from 0.87270
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 2.53219e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4202 - acc: 0.9136 - val_loss: 0.5667 - val_acc: 0.8675
#
# Epoch 00028: val_acc did not improve from 0.87270
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 2.21578e-05.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.4172 - acc: 0.9165 - val_loss: 0.5549 - val_acc: 0.8716
#
# Epoch 00029: val_acc did not improve from 0.87270
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 1.93029e-05.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4158 - acc: 0.9156 - val_loss: 0.5595 - val_acc: 0.8695
#
# Epoch 00030: val_acc did not improve from 0.87270
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 6.6966e-06.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4134 - acc: 0.9162 - val_loss: 0.5549 - val_acc: 0.8717
#
# Epoch 00031: val_acc did not improve from 0.87270
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 5.7824e-06.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4129 - acc: 0.9156 - val_loss: 0.5566 - val_acc: 0.8710
#
# Epoch 00032: val_acc did not improve from 0.87270
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 4.9711e-06.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4105 - acc: 0.9173 - val_loss: 0.5551 - val_acc: 0.8719
#
# Epoch 00033: val_acc did not improve from 0.87270
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 1.702e-06.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4094 - acc: 0.9185 - val_loss: 0.5560 - val_acc: 0.8711
#
# Epoch 00034: val_acc did not improve from 0.87270
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 1.4505e-06.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4081 - acc: 0.9180 - val_loss: 0.5574 - val_acc: 0.8710
#
# Epoch 00035: val_acc did not improve from 0.87270
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 1.2308e-06.
# 782/782 [==============================] - 48s 61ms/step - loss: 0.4084 - acc: 0.9181 - val_loss: 0.5525 - val_acc: 0.8715
#
# Epoch 00036: val_acc did not improve from 0.87270
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 4.224e-07.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4075 - acc: 0.9181 - val_loss: 0.5545 - val_acc: 0.8717
#
# Epoch 00037: val_acc did not improve from 0.87270
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 3.553e-07.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4049 - acc: 0.9201 - val_loss: 0.5540 - val_acc: 0.8715
#
# Epoch 00038: val_acc did not improve from 0.87270
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 2.976e-07.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4074 - acc: 0.9181 - val_loss: 0.5531 - val_acc: 0.8727
#
# Epoch 00039: val_acc did not improve from 0.87270
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 2.482e-07.
# 782/782 [==============================] - 51s 65ms/step - loss: 0.4072 - acc: 0.9185 - val_loss: 0.5539 - val_acc: 0.8716
#
# Epoch 00040: val_acc did not improve from 0.87270
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 2.061e-07.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.4068 - acc: 0.9183 - val_loss: 0.5545 - val_acc: 0.8717
#
# Epoch 00041: val_acc did not improve from 0.87270
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 1.705e-07.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.4083 - acc: 0.9177 - val_loss: 0.5526 - val_acc: 0.8722
#
# Epoch 00042: val_acc did not improve from 0.87270
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 1.404e-07.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.4082 - acc: 0.9187 - val_loss: 0.5531 - val_acc: 0.8717
#
# Epoch 00043: val_acc did not improve from 0.87270
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 1.151e-07.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4078 - acc: 0.9174 - val_loss: 0.5534 - val_acc: 0.8720
#
# Epoch 00044: val_acc did not improve from 0.87270
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 9.4e-08.
# 782/782 [==============================] - 48s 62ms/step - loss: 0.4076 - acc: 0.9187 - val_loss: 0.5533 - val_acc: 0.8722
#
# Epoch 00045: val_acc did not improve from 0.87270
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 7.65e-08.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4078 - acc: 0.9189 - val_loss: 0.5573 - val_acc: 0.8701
#
# Epoch 00046: val_acc did not improve from 0.87270
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 6.2e-08.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4062 - acc: 0.9185 - val_loss: 0.5518 - val_acc: 0.8728
#
# Epoch 00047: val_acc improved from 0.87270 to 0.87280, saving model to /content/saved_models/cifar10_ResNet20v2_model.047.h5
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 5e-08.
# 782/782 [==============================] - 49s 62ms/step - loss: 0.4077 - acc: 0.9188 - val_loss: 0.5522 - val_acc: 0.8722
#
# Epoch 00048: val_acc did not improve from 0.87280
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 4.02e-08.
# 782/782 [==============================] - 51s 66ms/step - loss: 0.4092 - acc: 0.9173 - val_loss: 0.5547 - val_acc: 0.8724
#
# Epoch 00049: val_acc did not improve from 0.87280
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 3.22e-08.
# 782/782 [==============================] - 49s 63ms/step - loss: 0.4098 - acc: 0.9174 - val_loss: 0.5549 - val_acc: 0.8719
#
# Epoch 00050: val_acc did not improve from 0.87280
# 10000/10000 [==============================] - 2s 216us/step
# Test loss: 0.5549327056407929
# Test accuracy: 0.8719
